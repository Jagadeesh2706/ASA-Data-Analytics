# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Retail_Sales_Dataset.csv')

# %%
df
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 0           T55703  2024-05-25     S009      P2255     Nike Running Shoes
# 1           T68113  2024-05-04     S001      P4998             Zara Dress
# 2           T15381  2025-01-31     S010      P1811                  Crocs
# 3           T35359  2024-03-04     S001      P5032         Organic Apples
# 4           T78348  2024-08-30     S007      P3588            Puma Jacket
# ..             ...         ...      ...        ...                    ...
# 495         T13187  2024-10-22     S009      P1234        Sony Headphones
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 498         T87917  2024-05-29     S002      P7645           GoPro Camera
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df.shape
# Out:
# (500, 12)

# %%
df.head()
# Out:
#   Transaction_ID        Date Store_ID Product_ID        Product_Name  \
# 0         T55703  2024-05-25     S009      P2255  Nike Running Shoes
# 1         T68113  2024-05-04     S001      P4998          Zara Dress
# 2         T15381  2025-01-31     S010      P1811               Crocs
# 3         T35359  2024-03-04     S001      P5032      Organic Apples
# 4         T78348  2024-08-30     S007      P3588         Puma Jacket
#
#     Category  Price  Quantity  Total_Sales Payment_Method  Customer_Age  \
# 0   Footwear    453         2          906            UPI            37
# 1   Clothing     94         1           94           Cash            65
# 2   Footwear    239         3          717     Debit Card            29
# 3  Groceries    913         4         3652            UPI            55
# 4   Clothing    254         5         1270    Credit Card            23
#
#   Customer_Gender
# 0      Non-Binary
# 1      Non-Binary
# 2            Male
# 3          Female
# 4          Female

# %%
df.tail()
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 495         T13187  2024-10-22     S009      P1234        Sony Headphones
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 498         T87917  2024-05-29     S002      P7645           GoPro Camera
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# 495      Electronics    110         1          110         PayPal
# 496        Groceries    809         2         1618         PayPal
# 497         Clothing    888         4         3552    Credit Card
# 498      Electronics    381         2          762     Debit Card
# 499  Home Appliances    609         1          609    Credit Card
#
#      Customer_Age Customer_Gender
# 495            52      Non-Binary
# 496            33      Non-Binary
# ...

# %%
df[20:25]
# Out:
#    Transaction_ID        Date Store_ID Product_ID     Product_Name  \
# 20         T45655  2024-07-31     S007      P7889  LG Refrigerator
# 21         T95001  2024-04-27     S008      P8000  Adidas Sneakers
# 22         T77298  2025-01-09     S004      P2282     GoPro Camera
# 23         T71437  2024-04-20     S010      P3217            Crocs
# 24         T35966  2024-10-12     S007      P6275  Sony Headphones
#
#            Category  Price  Quantity  Total_Sales Payment_Method  \
# 20  Home Appliances    627         5         3135     Debit Card
# 21         Footwear    828         2         1656           Cash
# 22      Electronics    481         3         1443         PayPal
# 23         Footwear    244         1          244    Credit Card
# 24      Electronics    283         5         1415     Debit Card
#
#     Customer_Age Customer_Gender
# 20            55          Female
# 21            34            Male
# 22            34      Non-Binary
# ...

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Store_ID', 'Product_ID', 'Product_Name',
#        'Category', 'Price', 'Quantity', 'Total_Sales', 'Payment_Method',
#        'Customer_Age', 'Customer_Gender'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Retail_Sales_Dataset.csv')
df
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 0           T55703  2024-05-25     S009      P2255     Nike Running Shoes
# 1           T68113  2024-05-04     S001      P4998             Zara Dress
# 2           T15381  2025-01-31     S010      P1811                  Crocs
# 3           T35359  2024-03-04     S001      P5032         Organic Apples
# 4           T78348  2024-08-30     S007      P3588            Puma Jacket
# ..             ...         ...      ...        ...                    ...
# 495         T13187  2024-10-22     S009      P1234        Sony Headphones
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 498         T87917  2024-05-29     S002      P7645           GoPro Camera
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Store_ID', 'Product_ID', 'Product_Name',
#        'Category', 'Price', 'Quantity', 'Total_Sales', 'Payment_Method',
#        'Customer_Age', 'Customer_Gender'],
#       dtype='object')

# %%
Transaction_ID=df['Transaction_ID']
Transaction_ID
# Out:
# 0      T55703
# 1      T68113
# 2      T15381
# 3      T35359
# 4      T78348
#         ...
# 495    T13187
# 496    T49727
# 497    T75992
# 498    T87917
# 499    T75967
# Name: Transaction_ID, Length: 500, dtype: object

# %%
df[["Transaction_ID","Product_ID"]].head()
# Out:
#   Transaction_ID Product_ID
# 0         T55703      P2255
# 1         T68113      P4998
# 2         T15381      P1811
# 3         T35359      P5032
# 4         T78348      P3588
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Transaction_ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df[["Transaction_ID","Product_ID"]].head()
# Out:
#   Transaction_ID Product_ID
# 0         T55703      P2255
# 1         T68113      P4998
# 2         T15381      P1811
# 3         T35359      P5032
# 4         T78348      P3588

# %%
df.loc[0:5,["Transaction_ID","Product_ID"]]
# Out:
#   Transaction_ID Product_ID
# 0         T55703      P2255
# 1         T68113      P4998
# 2         T15381      P1811
# 3         T35359      P5032
# 4         T78348      P3588
# 5         T39689      P5433

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Price"].max()
# Out:
# 996

# %%
df["Price"].min()
# Out:
# 10

# %%
df["Price"].mean()
# Out:
# 510.692

# %%
df["Price"].std()
# Out:
# 284.81476090972535

# %%
df.describe()
# Out:
#             Price   Quantity  Total_Sales  Customer_Age
# count  500.000000  500.00000    500.00000    500.000000
# mean   510.692000    2.99000   1537.14600     44.372000
# std    284.814761    1.43737   1195.01008     14.637422
# min     10.000000    1.00000     12.00000     18.000000
# 25%    265.250000    2.00000    564.50000     33.000000
# 50%    526.500000    3.00000   1216.00000     44.000000
# 75%    746.500000    4.00000   2394.00000     57.000000
# max    996.000000    5.00000   4970.00000     70.000000

# %%
df[df["Price"]>500]
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 3           T35359  2024-03-04     S001      P5032         Organic Apples
# 6           T77121  2024-09-29     S004      P5264        LG Refrigerator
# 10          T69323  2024-09-17     S006      P8291              Olive Oil
# 11          T87082  2024-07-16     S005      P3672              Olive Oil
# 12          T46136  2024-08-31     S004      P7863             Zara Dress
# ..             ...         ...      ...        ...                    ...
# 493         T10013  2024-02-04     S006      P3553         Adidas T-Shirt
# 494         T65288  2024-06-21     S004      P8763        Puma Flip-Flops
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df[df["Price"]==df["Price"].max()]
# Out:
#     Transaction_ID        Date Store_ID Product_ID Product_Name   Category  \
# 117         T60887  2024-03-22     S007      P2376  Brown Bread  Groceries
#
#      Price  Quantity  Total_Sales Payment_Method  Customer_Age Customer_Gender
# 117    996         3         2988     Debit Card            46          Female

# %%
df[df["Price"]==df["Price"].min()]
# Out:
#    Transaction_ID        Date Store_ID Product_ID    Product_Name   Category  \
# 60         T96707  2024-05-22     S005      P5445  Organic Apples  Groceries
#
#     Price  Quantity  Total_Sales Payment_Method  Customer_Age Customer_Gender
# 60     10         2           20         PayPal            62      Non-Binary

# %%
df["Transaction_ID"][df["Price"] < 100]
# Out:
# 1      T68113
# 16     T52168
# 28     T57019
# 48     T14256
# 60     T96707
# 62     T54163
# 76     T16965
# 87     T88021
# 94     T73563
# 96     T35813
# 112    T23578
# 131    T84634
# 137    T86288
# 142    T59229
# 144    T57694
# 151    T70998
# 174    T57607
# 179    T84203
# 183    T11886
# 195    T51861
# 201    T75409
# 227    T81232
# 229    T80863
# 233    T63438
# 273    T12512
# 286    T16584
# 288    T32257
# 306    T62865
# 308    T65240
# 309    T22627
# 316    T82269
# 329    T81622
# 390    T47416
# 395    T30463
# 397    T82113
# 402    T66152
# 408    T94630
# 412    T13241
# 417    T66264
# 422    T96242
# 439    T30765
# 447    T99264
# 462    T77631
# 485    T59543
# 490    T95514
# Name: Transaction_ID, dtype: object

# %%
df.loc[0]
# Out:
# Transaction_ID                 T55703
# Date                       2024-05-25
# Store_ID                         S009
# Product_ID                      P2255
# Product_Name       Nike Running Shoes
# Category                     Footwear
# Price                             453
# Quantity                            2
# Total_Sales                       906
# Payment_Method                    UPI
# Customer_Age                       37
# Customer_Gender            Non-Binary
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Transaction_ID                 T55703
# Date                       2024-05-25
# Store_ID                         S009
# Product_ID                      P2255
# Product_Name       Nike Running Shoes
# Category                     Footwear
# Price                             453
# Quantity                            2
# Total_Sales                       906
# Payment_Method                    UPI
# Customer_Age                       37
# Customer_Gender            Non-Binary
# Name: 0, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.loc['T55703']
# Out:
# Date                       2024-05-25
# Store_ID                         S009
# Product_ID                      P2255
# Product_Name       Nike Running Shoes
# Category                     Footwear
# Price                             453
# Quantity                            2
# Total_Sales                       906
# Payment_Method                    UPI
# Customer_Age                       37
# Customer_Gender            Non-Binary
# Name: T55703, dtype: object

# %%
df.iloc[3]
# Out:
# Date                   2024-03-04
# Store_ID                     S001
# Product_ID                  P5032
# Product_Name       Organic Apples
# Category                Groceries
# Price                         913
# Quantity                        4
# Total_Sales                  3652
# Payment_Method                UPI
# Customer_Age                   55
# Customer_Gender            Female
# Name: T35359, dtype: object

# %%
df.head()
# Out:
#          Date Store_ID Product_ID        Product_Name   Category  Price  \
# 0  2024-05-25     S009      P2255  Nike Running Shoes   Footwear    453
# 1  2024-05-04     S001      P4998          Zara Dress   Clothing     94
# 2  2025-01-31     S010      P1811               Crocs   Footwear    239
# 3  2024-03-04     S001      P5032      Organic Apples  Groceries    913
# 4  2024-08-30     S007      P3588         Puma Jacket   Clothing    254
#
#    Quantity  Total_Sales Payment_Method  Customer_Age Customer_Gender
# 0         2          906            UPI            37      Non-Binary
# 1         1           94           Cash            65      Non-Binary
# 2         3          717     Debit Card            29            Male
# 3         4         3652            UPI            55          Female
# 4         5         1270    Credit Card            23          Female

# %%
df=pd.read_csv('/content/Retail_Sales_Dataset.csv')
df
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 0           T55703  2024-05-25     S009      P2255     Nike Running Shoes
# 1           T68113  2024-05-04     S001      P4998             Zara Dress
# 2           T15381  2025-01-31     S010      P1811                  Crocs
# 3           T35359  2024-03-04     S001      P5032         Organic Apples
# 4           T78348  2024-08-30     S007      P3588            Puma Jacket
# ..             ...         ...      ...        ...                    ...
# 495         T13187  2024-10-22     S009      P1234        Sony Headphones
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 498         T87917  2024-05-29     S002      P7645           GoPro Camera
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.isnull()
# Out:
#      Transaction_ID   Date  Store_ID  Product_ID  Product_Name  Category  \
# 0             False  False     False       False         False     False
# 1             False  False     False       False         False     False
# 2             False  False     False       False         False     False
# 3             False  False     False       False         False     False
# 4             False  False     False       False         False     False
# ..              ...    ...       ...         ...           ...       ...
# 495           False  False     False       False         False     False
# 496           False  False     False       False         False     False
# 497           False  False     False       False         False     False
# 498           False  False     False       False         False     False
# 499           False  False     False       False         False     False
#
#      Price  Quantity  Total_Sales  Payment_Method  Customer_Age  \
# ...

# %%
df.isnull().sum()
# Out:
# Transaction_ID     0
# Date               0
# Store_ID           0
# Product_ID         0
# Product_Name       0
# Category           0
# Price              0
# Quantity           0
# Total_Sales        0
# Payment_Method     0
# Customer_Age       0
# Customer_Gender    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#   Transaction_ID        Date Store_ID Product_ID        Product_Name  \
# 0         T55703  2024-05-25     S009      P2255  Nike Running Shoes
# 1         T68113  2024-05-04     S001      P4998          Zara Dress
# 2         T15381  2025-01-31     S010      P1811               Crocs
# 3         T35359  2024-03-04     S001      P5032      Organic Apples
# 4         T78348  2024-08-30     S007      P3588         Puma Jacket
# 5         T39689  2024-03-16     S003      P5433      Adidas T-Shirt
# 6         T77121  2024-09-29     S004      P5264     LG Refrigerator
# 7         T27358  2024-05-28     S003      P7766        Levi's Jeans
# 8         T30993  2024-07-18     S006      P3693     Sony Headphones
# 9         T42023  2024-10-04     S003      P9365         Instant Pot
#
#           Category  Price  Quantity  Total_Sales Payment_Method  Customer_Age  \
# 0         Footwear    453         2          906            UPI            37
# ...

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Store_ID', 'Product_ID', 'Product_Name',
#        'Category', 'Price', 'Quantity', 'Total_Sales', 'Payment_Method',
#        'Customer_Age', 'Customer_Gender'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Transaction_ID     object
# Date               object
# Store_ID           object
# Product_ID         object
# Product_Name       object
# Category           object
# Price               int64
# Quantity            int64
# Total_Sales         int64
# Payment_Method     object
# Customer_Age        int64
# Customer_Gender    object
# dtype: object

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Category'], palette='viridis')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.title('Category Distribution')
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-74-204c1481381e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Category'], palette='viridis')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Quantity'],palette='viridis')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.title('Quantity Distribution')
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-77-f1bdf6e349bb>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Quantity'],palette='viridis')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df["Customer_Gender"],palette='viridis')
plt.xlabel("Customer_Gender")
plt.ylabel("frequency")
plt.title("Customer_Gender")
plt.show()
# Out:
# <ipython-input-81-25de35aed158>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Customer_Gender"],palette='viridis')

# %%
product_counts = df['Category'].value_counts()
product_counts
# Out:
# Category
# Electronics        113
# Home Appliances    102
# Footwear           100
# Clothing            96
# Groceries           89
# Name: count, dtype: int64

# %%
df["Category"].unique()
# Out:
# array(['Footwear', 'Clothing', 'Groceries', 'Home Appliances',
#        'Electronics'], dtype=object)

# %%
df['Category'].max()
# Out:
# 'Home Appliances'

# %%
df.loc[df['Category'] == 'Home Appliances']
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 6           T77121  2024-09-29     S004      P5264        LG Refrigerator
# 9           T42023  2024-10-04     S003      P9365            Instant Pot
# 19          T26691  2024-05-25     S004      P8141            Instant Pot
# 20          T45655  2024-07-31     S007      P7889        LG Refrigerator
# 27          T22348  2025-01-02     S002      P7715      Philips Air Fryer
# ..             ...         ...      ...        ...                    ...
# 461         T28972  2024-08-23     S005      P8835  Bosch Washing Machine
# 464         T82190  2024-04-03     S002      P1196            Instant Pot
# 476         T29175  2024-04-09     S010      P2236           Dyson Vacuum
# 478         T95999  2024-06-24     S007      P8127  Bosch Washing Machine
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])
df['month']=df['Date'].dt.to_period('M')
monthly_sales=df.groupby('month')['Total_Sales'].sum()
monthly_sales
# Out:
# month
# 2024-02    44792
# 2024-03    62512
# 2024-04    67598
# 2024-05    69109
# 2024-06    74499
# 2024-07    59369
# 2024-08    56570
# 2024-09    80248
# 2024-10    84207
# 2024-11    63524
# 2024-12    49904
# 2025-01    50077
# 2025-02     6164
# Freq: M, Name: Total_Sales, dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])
df['month']=df['Date'].dt.to_period('M')
monthly_sales=df.groupby('Date')['Total_Sales'].sum()
plt.figure(figsize=(20,5))
monthly_sales.plot(kind='line', marker='o', color='b')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/Retail_Sales_Dataset.csv')
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Total_Sales'].sum()
monthly_sales.index = monthly_sales.index.astype(str)
plt.figure(figsize=(20, 5))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', color='b', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales')
plt.xticks(rotation=45)

plt.grid()
plt.show()

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].dt.to_period('M')
df['Month']
# Out:
# 0      2024-05
# 1      2024-05
# 2      2025-01
# 3      2024-03
# 4      2024-08
#         ...
# 495    2024-10
# 496    2024-06
# 497    2024-12
# 498    2024-05
# 499    2024-08
# Name: Month, Length: 500, dtype: period[M]

# %%
df['Date']=pd.to_datetime(df['Date'])
df['week']=df['Date'].dt.to_period('w')
df['week']
# Out:
# <ipython-input-16-1e456ef308a0>:2: FutureWarning: 'w' is deprecated and will be removed in a future version, please use 'W' instead.
#   df['week']=df['Date'].dt.to_period('w')
# 0      2024-05-20/2024-05-26
# 1      2024-04-29/2024-05-05
# 2      2025-01-27/2025-02-02
# 3      2024-03-04/2024-03-10
# 4      2024-08-26/2024-09-01
#                ...
# 495    2024-10-21/2024-10-27
# 496    2024-06-10/2024-06-16
# 497    2024-12-23/2024-12-29
# 498    2024-05-27/2024-06-02
# 499    2024-08-19/2024-08-25
# Name: week, Length: 500, dtype: period[W-SUN]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Retail_Sales_Dataset.csv')
df
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 0           T55703  2024-05-25     S009      P2255     Nike Running Shoes
# 1           T68113  2024-05-04     S001      P4998             Zara Dress
# 2           T15381  2025-01-31     S010      P1811                  Crocs
# 3           T35359  2024-03-04     S001      P5032         Organic Apples
# 4           T78348  2024-08-30     S007      P3588            Puma Jacket
# ..             ...         ...      ...        ...                    ...
# 495         T13187  2024-10-22     S009      P1234        Sony Headphones
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 498         T87917  2024-05-29     S002      P7645           GoPro Camera
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df.rename(columns={'Date':'DataFrame index'},inplace=True)
df
# Out:
#     Transaction_ID DataFrame index Store_ID Product_ID           Product_Name  \
# 0           T55703      2024-05-25     S009      P2255     Nike Running Shoes
# 1           T68113      2024-05-04     S001      P4998             Zara Dress
# 2           T15381      2025-01-31     S010      P1811                  Crocs
# 3           T35359      2024-03-04     S001      P5032         Organic Apples
# 4           T78348      2024-08-30     S007      P3588            Puma Jacket
# ..             ...             ...      ...        ...                    ...
# 495         T13187      2024-10-22     S009      P1234        Sony Headphones
# 496         T49727      2024-06-14     S010      P8689         Organic Apples
# 497         T75992      2024-12-28     S010      P6451             Zara Dress
# 498         T87917      2024-05-29     S002      P7645           GoPro Camera
# 499         T75967      2024-08-23     S007      P7689  Bosch Washing Machine
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/Retail_Sales_Dataset.csv')
numerical_cols = df.select_dtypes(include=np.number)


correlation_matrix = numerical_cols.corr()


plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Overall Correlation Matrix for Numerical Columns')
plt.show()

# %%
df.loc[0]
# Out:
# Transaction_ID                 T55703
# Date                       2024-05-25
# Store_ID                         S009
# Product_ID                      P2255
# Product_Name       Nike Running Shoes
# Category                     Footwear
# Price                             453
# Quantity                            2
# Total_Sales                       906
# Payment_Method                    UPI
# Customer_Age                       37
# Customer_Gender            Non-Binary
# Name: 0, dtype: object

# %%
df.loc[df['Product_Name']=='Organic Apples']
# Out:
#     Transaction_ID        Date Store_ID Product_ID    Product_Name   Category  \
# 3           T35359  2024-03-04     S001      P5032  Organic Apples  Groceries
# 32          T32563  2024-07-24     S006      P4321  Organic Apples  Groceries
# 34          T93090  2024-08-01     S002      P1577  Organic Apples  Groceries
# 43          T10528  2024-06-23     S006      P6049  Organic Apples  Groceries
# 60          T96707  2024-05-22     S005      P5445  Organic Apples  Groceries
# 72          T41387  2024-10-26     S007      P2353  Organic Apples  Groceries
# 138         T21959  2024-08-19     S009      P8580  Organic Apples  Groceries
# 149         T21365  2024-12-01     S008      P2832  Organic Apples  Groceries
# 151         T70998  2024-12-13     S003      P7789  Organic Apples  Groceries
# 153         T64267  2024-04-28     S003      P3110  Organic Apples  Groceries
# 171         T86722  2024-06-25     S010      P2241  Organic Apples  Groceries
# ...

# %%
df.iloc[497]
# Out:
# Transaction_ID          T75992
# Date                2024-12-28
# Store_ID                  S010
# Product_ID               P6451
# Product_Name        Zara Dress
# Category              Clothing
# Price                      888
# Quantity                     4
# Total_Sales               3552
# Payment_Method     Credit Card
# Customer_Age                28
# Customer_Gender     Non-Binary
# Name: 497, dtype: object

# %%
df.drop('Product_Name',axis=1)
# Out:
#     Transaction_ID        Date Store_ID Product_ID         Category  Price  \
# 0           T55703  2024-05-25     S009      P2255         Footwear    453
# 1           T68113  2024-05-04     S001      P4998         Clothing     94
# 2           T15381  2025-01-31     S010      P1811         Footwear    239
# 3           T35359  2024-03-04     S001      P5032        Groceries    913
# 4           T78348  2024-08-30     S007      P3588         Clothing    254
# ..             ...         ...      ...        ...              ...    ...
# 495         T13187  2024-10-22     S009      P1234      Electronics    110
# 496         T49727  2024-06-14     S010      P8689        Groceries    809
# 497         T75992  2024-12-28     S010      P6451         Clothing    888
# 498         T87917  2024-05-29     S002      P7645      Electronics    381
# 499         T75967  2024-08-23     S007      P7689  Home Appliances    609
#
# ...

# %%
df.drop(index=1, axis=0)
# Out:
#     Transaction_ID        Date Store_ID Product_ID           Product_Name  \
# 0           T55703  2024-05-25     S009      P2255     Nike Running Shoes
# 2           T15381  2025-01-31     S010      P1811                  Crocs
# 3           T35359  2024-03-04     S001      P5032         Organic Apples
# 4           T78348  2024-08-30     S007      P3588            Puma Jacket
# 5           T39689  2024-03-16     S003      P5433         Adidas T-Shirt
# ..             ...         ...      ...        ...                    ...
# 495         T13187  2024-10-22     S009      P1234        Sony Headphones
# 496         T49727  2024-06-14     S010      P8689         Organic Apples
# 497         T75992  2024-12-28     S010      P6451             Zara Dress
# 498         T87917  2024-05-29     S002      P7645           GoPro Camera
# 499         T75967  2024-08-23     S007      P7689  Bosch Washing Machine
#
#             Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
df.iloc[0:10]
# Out:
#   Transaction_ID        Date Store_ID Product_ID        Product_Name  \
# 0         T55703  2024-05-25     S009      P2255  Nike Running Shoes
# 1         T68113  2024-05-04     S001      P4998          Zara Dress
# 2         T15381  2025-01-31     S010      P1811               Crocs
# 3         T35359  2024-03-04     S001      P5032      Organic Apples
# 4         T78348  2024-08-30     S007      P3588         Puma Jacket
# 5         T39689  2024-03-16     S003      P5433      Adidas T-Shirt
# 6         T77121  2024-09-29     S004      P5264     LG Refrigerator
# 7         T27358  2024-05-28     S003      P7766        Levi's Jeans
# 8         T30993  2024-07-18     S006      P3693     Sony Headphones
# 9         T42023  2024-10-04     S003      P9365         Instant Pot
#
#           Category  Price  Quantity  Total_Sales Payment_Method  Customer_Age  \
# 0         Footwear    453         2          906            UPI            37
# ...

# %%
df.loc[0:10]
# Out:
#    Transaction_ID        Date Store_ID Product_ID        Product_Name  \
# 0          T55703  2024-05-25     S009      P2255  Nike Running Shoes
# 1          T68113  2024-05-04     S001      P4998          Zara Dress
# 2          T15381  2025-01-31     S010      P1811               Crocs
# 3          T35359  2024-03-04     S001      P5032      Organic Apples
# 4          T78348  2024-08-30     S007      P3588         Puma Jacket
# 5          T39689  2024-03-16     S003      P5433      Adidas T-Shirt
# 6          T77121  2024-09-29     S004      P5264     LG Refrigerator
# 7          T27358  2024-05-28     S003      P7766        Levi's Jeans
# 8          T30993  2024-07-18     S006      P3693     Sony Headphones
# 9          T42023  2024-10-04     S003      P9365         Instant Pot
# 10         T69323  2024-09-17     S006      P8291           Olive Oil
#
#            Category  Price  Quantity  Total_Sales Payment_Method  \
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(y=df['Product_Name'],palette='viridis')
plt.xlabel('Payment_Method')
plt.ylabel('Frequency')
plt.title('Payment_Method Distribution')
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-34-ee123f8301a5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Product_Name'],palette='viridis')

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Cash           108
# UPI            106
# PayPal         103
# Debit Card     101
# Credit Card     82
# Name: count, dtype: int64
